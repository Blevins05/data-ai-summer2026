# %% [markdown]
# <a href="https://colab.research.google.com/github/Blevins05/data-ai-summer2026/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analisis de un dataset de partidos de LaLiga 2019-2025

# %% [markdown]
# Repasando análisis de datos básico con pandas, y luego visualización con matplotlib y seaborn. La base del análisis de datos.

# %% [markdown]
# Mediante `read_csv()` podemos cargar un CSV en pandas.
#
# También podemos trabajar con `
# .xlxx` o `.tsv`

# %%
import pandas as pd
data = pd.read_csv("matches_laliga.csv")

# %% [markdown]
# Mediante el método `head()`, muestro las primeras 5 instancias del dataset de partidos.
#
# Existe igualmente `tail()`, que muestra las 5 últimas.

# %%
data.head()
# Out:
#    Unnamed: 0        date   time     comp        round  day venue result   gf  \
# 0           0  2025-08-16  19:30  La Liga  Matchweek 1  Sat  Away      W  3.0
# 1           1  2025-08-23  21:30  La Liga  Matchweek 2  Sat  Away      W  3.0
# 2           2  2025-08-31  21:30  La Liga  Matchweek 3  Sun  Away      D  1.0
# 3           3  2025-09-14  21:00  La Liga  Matchweek 4  Sun  Home      W  6.0
# 4           5  2025-09-21  21:00  La Liga  Matchweek 5  Sun  Home      W  3.0
#
#     ga  ...  match report  notes    sh   sot  dist   fk pk pkatt season  \
# 0  0.0  ...  Match Report    NaN  24.0   8.0  18.9  1.0  0     0   2025
# 1  2.0  ...  Match Report    NaN  26.0  10.0  17.0  1.0  0     0   2025
# 2  1.0  ...  Match Report    NaN  11.0   2.0  20.3  0.0  1     1   2025
# 3  0.0  ...  Match Report    NaN  24.0  10.0  18.4  0.0  0     0   2025
# 4  0.0  ...  Match Report    NaN  16.0   7.0  18.2  2.0  0     0   2025
#
#         team
# 0  Barcelona
# 1  Barcelona
# 2  Barcelona
# 3  Barcelona
# 4  Barcelona
#
# [5 rows x 29 columns]

# %%
data.tail()
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 4695          48  2020-07-05  17:00  La Liga  Matchweek 34  Sun  Home      L
# 4696          49  2020-07-08  22:00  La Liga  Matchweek 35  Wed  Away      L
# 4697          50  2020-07-12  14:00  La Liga  Matchweek 36  Sun  Home      L
# 4698          51  2020-07-16  21:00  La Liga  Matchweek 37  Thu  Away      L
# 4699          52  2020-07-19  21:00  La Liga  Matchweek 38  Sun  Home      D
#
#        gf   ga  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 4695  0.0  1.0  ...  Match Report    NaN   7.0  2.0  18.9  1.0  0     0
# 4696  0.0  1.0  ...  Match Report    NaN  11.0  2.0  18.1  1.0  0     0
# 4697  0.0  2.0  ...  Match Report    NaN  14.0  3.0  20.8  3.0  0     0
# 4698  0.0  1.0  ...  Match Report    NaN  18.0  6.0  21.3  3.0  0     0
# 4699  0.0  0.0  ...  Match Report    NaN   8.0  1.0  17.2  0.0  0     0
#
#      season      team
# 4695   2019  Espanyol
# 4696   2019  Espanyol
# 4697   2019  Espanyol
# 4698   2019  Espanyol
# 4699   2019  Espanyol
#
# [5 rows x 29 columns]

# %% [markdown]
# En los notebooks de Jupyter, los DataFrames de Pandas se muestran usando las tablas vistas en la celda anterior.
#
# En este caso cada fila corresponde con un cliente, una **instancia**, y las columnas son los **descriptores** de dicha instancia.

# %% [markdown]
# Vamos ahora a ver las dimensiones de nuestros datos, los nombres de los descriptores, y los tipos de los descriptores.
#
# La siguiente función nos muestra la dimensión del dataset.

# %%
print(data.shape)
# Out:
# (4700, 29)

# %% [markdown]
# El dataset de fútbol tiene 4700 instancias, es decir se han jugado 4700 partidos de Primera División Española desde 2019. Para cada partido tenemos 29 descriptores.

# %% [markdown]
# El atributo `columns` sirve para mostrar los nombres de las columnas o descriptores

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'opp formation', 'referee', 'match report', 'notes', 'sh',
#        'sot', 'dist', 'fk', 'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %% [markdown]
# Por último, el método `info()` ayuda a ver más información general sobre el DataFrame

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4700 entries, 0 to 4699
# Data columns (total 29 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     4700 non-null   int64
#  1   date           4700 non-null   object
#  2   time           4700 non-null   object
#  3   comp           4700 non-null   object
#  4   round          4700 non-null   object
#  5   day            4700 non-null   object
#  6   venue          4700 non-null   object
#  7   result         4700 non-null   object
#  8   gf             4700 non-null   float64
#  9   ga             4700 non-null   float64
#  10  opponent       4700 non-null   object
#  11  xg             4700 non-null   float64
#  12  xga            4700 non-null   float64
#  13  poss           4700 non-null   float64
#  14  attendance     3724 non-null   float64
#  15  captain        4700 non-null   object
#  16  formation      4700 non-null   object
#  17  opp formation  4700 non-null   object
#  18  referee        4700 non-null   object
#  19  match report   4700 non-null   object
#  20  notes          0 non-null      float64
#  21  sh             4700 non-null   float64
#  22  sot            4700 non-null   float64
#  23  dist           4697 non-null   float64
#  24  fk             4700 non-null   float64
#  25  pk             4700 non-null   int64
#  26  pkatt          4700 non-null   int64
#  27  season         4700 non-null   int64
#  28  team           4700 non-null   object
# dtypes: float64(11), int64(4), object(14)
# memory usage: 1.0+ MB
# None

# %% [markdown]
# Se puede ver cada uno de los descriptores y el tipo de dato que son.

# %% [markdown]
# Es posible transformar el tipo de dato de un descriptor mediante el método `astype()`

# %% [markdown]
# Por ejemplo: (aunque no hace falta)

# %%
data['gf'] = data['gf'].astype('float')

# %%
print(data['gf'])
# Out:
# 0       3.0
# 1       3.0
# 2       1.0
# 3       6.0
# 4       3.0
#        ...
# 4695    0.0
# 4696    0.0
# 4697    0.0
# 4698    0.0
# 4699    0.0
# Name: gf, Length: 4700, dtype: float64

# %% [markdown]
# El método `describe()` aporta estadísticas básicas de cada descriptor numérico. En concreto, el número de nulos, la media, la desv. típica, el rango (mediante los valores min, max), la mediana indicada con el cuartil 50 y los cuartiles .25 y .75

# %%
data.describe()
# Out:
#         Unnamed: 0           gf           ga           xg          xga  \
# count  4700.000000  4700.000000  4700.000000  4700.000000  4700.000000
# mean     22.061702     1.273617     1.273617     1.264532     1.264532
# std      14.395784     1.165048     1.165048     0.776251     0.776251
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       9.000000     0.000000     0.000000     0.700000     0.700000
# 50%      22.000000     1.000000     1.000000     1.100000     1.100000
# 75%      34.000000     2.000000     2.000000     1.700000     1.700000
# max      60.000000     7.000000     7.000000     5.900000     5.900000
#
#               poss    attendance  notes           sh          sot  \
# count  4700.000000   3724.000000    0.0  4700.000000  4700.000000
# mean     50.001064  28097.842105    NaN    11.550213     3.804468
# std      11.509529  18104.760706    NaN     4.906037     2.296370
# min      18.000000     13.000000    NaN     0.000000     0.000000
# 25%      42.000000  14266.000000    NaN     8.000000     2.000000
# 50%      50.000000  20298.500000    NaN    11.000000     3.000000
# 75%      58.000000  39957.000000    NaN    14.000000     5.000000
# max      82.000000  95745.000000    NaN    40.000000    17.000000
#
#               dist           fk           pk        pkatt       season
# count  4697.000000  4700.000000  4700.000000  4700.000000  4700.000000
# mean     18.154652     0.443191     0.130426     0.168936  2021.604255
# std       3.386085     0.688555     0.362374     0.415661     1.784514
# min       4.800000     0.000000     0.000000     0.000000  2019.000000
# 25%      15.900000     0.000000     0.000000     0.000000  2020.000000
# 50%      18.000000     0.000000     0.000000     0.000000  2022.000000
# 75%      20.000000     1.000000     0.000000     0.000000  2023.000000
# max      46.200000     5.000000     3.000000     3.000000  2025.000000

# %% [markdown]
# Para visualizar stats de descriptores no numéricos, hay que indicar los tipos de datos que interesa mirar en el parámetro ´include´

# %%
data.describe(include=['object'])
# Out:
#               date   time     comp        round   day venue result  opponent  \
# count         4700   4700     4700         4700  4700  4700   4700      4700
# unique         839     21        1           38     7     2      3        28
# top     2025-05-18  21:00  La Liga  Matchweek 1   Sun  Away      W  Valencia
# freq            20   1328     4700          140  1770  2350   1712       235
#
#        captain formation opp formation     referee  match report       team
# count     4700      4700          4700        4700          4700       4700
# unique     245        22            21          36             1         28
# top      Djené     4-4-2         4-4-2  César Soto  Match Report  Barcelona
# freq       183      1298          1298         252          4700        235

# %% [markdown]
# Para descriptores categóricos (de tipo `object`) y booleanos (tipo `bool`), podemos usar el método `value_counts`.

# %%
data['formation'].value_counts()
# Out:
# formation
# 4-4-2         1298
# 4-2-3-1       1194
# 4-3-3          750
# 4-1-4-1        321
# 5-3-2          277
# 3-4-3          219
# 5-4-1          127
# 3-5-2           98
# 4-1-3-2         98
# 4-4-1-1         84
# 3-1-4-2         59
# 4-5-1           56
# 4-1-2-1-2◆      34
# 4-3-1-2         31
# 3-4-1-2         26
# 4-2-2-2         14
# 3-5-1-1          6
# 4-3-2-1          3
# 3-4-3◆           2
# 3-2-4-1          1
# 4-2-4-0          1
# 3-3-3-1          1
# Name: count, dtype: int64

# %% [markdown]
# La formación más usada durante estos años ha sido una 4-4-2, seguida de cerca por el 4-2-3-1

# %% [markdown]
# Si quisieramos visualizarlo en porcentajes, utilizariamos el parámetro `normalize=True`

# %%
data['formation'].value_counts(normalize=True)
# Out:
# formation
# 4-4-2         0.276170
# 4-2-3-1       0.254043
# 4-3-3         0.159574
# 4-1-4-1       0.068298
# 5-3-2         0.058936
# 3-4-3         0.046596
# 5-4-1         0.027021
# 3-5-2         0.020851
# 4-1-3-2       0.020851
# 4-4-1-1       0.017872
# 3-1-4-2       0.012553
# 4-5-1         0.011915
# 4-1-2-1-2◆    0.007234
# 4-3-1-2       0.006596
# 3-4-1-2       0.005532
# 4-2-2-2       0.002979
# 3-5-1-1       0.001277
# 4-3-2-1       0.000638
# 3-4-3◆        0.000426
# 3-2-4-1       0.000213
# 4-2-4-0       0.000213
# 3-3-3-1       0.000213
# Name: proportion, dtype: float64

# %% [markdown]
# Casi un 28% de los partidos emplea una formación 4-4-2

# %% [markdown]
# Los dataframes los podemos ordenar también mediante 1 de sus descriptores o mediante varios. Esto a su vez se puede hacer de manera ascendiente o descendiente.
#
# Empleamos 2 cosas: el método `sort_values`, y el parámetro `ascending`

# %% [markdown]
# Ordeno por número de goles

# %%
data.sort_values(by='poss', ascending=False)
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 2437          23  2021-12-19  21:00  La Liga  Matchweek 18  Sun  Home      D
# 3265          14  2020-12-05  21:00  La Liga  Matchweek 12  Sat  Away      L
# 3278          35  2021-02-21  14:00  La Liga  Matchweek 24  Sun  Home      D
# 3288          48  2021-04-29  19:00  La Liga  Matchweek 33  Thu  Home      L
# 3997          26  2020-01-19  21:00  La Liga  Matchweek 20  Sun  Home      W
# ...          ...         ...    ...      ...           ...  ...   ...    ...
# 895           36  2025-05-03  21:00  La Liga  Matchweek 34  Sat  Home      L
# 99             1  2025-08-23  21:30  La Liga   Matchweek 2  Sat  Home      L
# 3621          26  2021-02-21  14:00  La Liga  Matchweek 24  Sun  Away      D
# 3609          11  2020-12-05  21:00  La Liga  Matchweek 12  Sat  Home      W
# 3045          19  2021-12-19  21:00  La Liga  Matchweek 18  Sun  Away      D
#
#        gf   ga  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 2437  0.0  0.0  ...  Match Report    NaN  36.0  9.0  19.0  2.0  0     0
# 3265  1.0  2.0  ...  Match Report    NaN  21.0  8.0  20.6  4.0  0     0
# 3278  1.0  1.0  ...  Match Report    NaN  19.0  3.0  19.4  0.0  1     1
# 3288  1.0  2.0  ...  Match Report    NaN  16.0  4.0  17.1  1.0  0     0
# 3997  1.0  0.0  ...  Match Report    NaN  18.0  6.0  21.2  3.0  0     0
# ...   ...  ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 895   1.0  2.0  ...  Match Report    NaN   5.0  4.0  11.6  0.0  0     0
# 99    2.0  3.0  ...  Match Report    NaN   7.0  4.0  13.5  0.0  1     1
# 3621  1.0  1.0  ...  Match Report    NaN   2.0  0.0  19.4  0.0  1     1
# 3609  2.0  1.0  ...  Match Report    NaN   7.0  3.0  15.8  1.0  0     0
# 3045  0.0  0.0  ...  Match Report    NaN   4.0  0.0  18.4  0.0  0     0
#
#      season         team
# 2437   2021  Real Madrid
# 3265   2020    Barcelona
# 3278   2020    Barcelona
# 3288   2020    Barcelona
# 3997   2019    Barcelona
# ...     ...          ...
# 895    2024   Valladolid
# 99     2025      Levante
# 3621   2020        Cadiz
# 3609   2020        Cadiz
# 3045   2021        Cadiz
#
# [4700 rows x 29 columns]

# %% [markdown]
# El equipo con más posesión en un partido, es el Real Madrid con un 82% de posesión, frente al Cádiz, el 19 de diciembre de la temporada 21/22 que acabo 0-0.

# %% [markdown]
# También se puede ordenar por múltiples descriptores.

# %%
data.sort_values(by=["poss", 'gf'], ascending=[False, False])
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 3265          14  2020-12-05  21:00  La Liga  Matchweek 12  Sat  Away      L
# 2437          23  2021-12-19  21:00  La Liga  Matchweek 18  Sun  Home      D
# 1              1  2025-08-23  21:30  La Liga   Matchweek 2  Sat  Away      W
# 173           54  2025-05-03  21:00  La Liga  Matchweek 34  Sat  Away      W
# 3278          35  2021-02-21  14:00  La Liga  Matchweek 24  Sun  Home      D
# ...          ...         ...    ...      ...           ...  ...   ...    ...
# 895           36  2025-05-03  21:00  La Liga  Matchweek 34  Sat  Home      L
# 3621          26  2021-02-21  14:00  La Liga  Matchweek 24  Sun  Away      D
# 4187          19  2020-01-19  21:00  La Liga  Matchweek 20  Sun  Away      L
# 3609          11  2020-12-05  21:00  La Liga  Matchweek 12  Sat  Home      W
# 3045          19  2021-12-19  21:00  La Liga  Matchweek 18  Sun  Away      D
#
#        gf   ga  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 3265  1.0  2.0  ...  Match Report    NaN  21.0   8.0  20.6  4.0  0     0
# 2437  0.0  0.0  ...  Match Report    NaN  36.0   9.0  19.0  2.0  0     0
# 1     3.0  2.0  ...  Match Report    NaN  26.0  10.0  17.0  1.0  0     0
# 173   2.0  1.0  ...  Match Report    NaN  24.0   6.0  17.4  3.0  0     0
# 3278  1.0  1.0  ...  Match Report    NaN  19.0   3.0  19.4  0.0  1     1
# ...   ...  ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 895   1.0  2.0  ...  Match Report    NaN   5.0   4.0  11.6  0.0  0     0
# 3621  1.0  1.0  ...  Match Report    NaN   2.0   0.0  19.4  0.0  1     1
# 4187  0.0  1.0  ...  Match Report    NaN   5.0   1.0  26.1  1.0  0     0
# 3609  2.0  1.0  ...  Match Report    NaN   7.0   3.0  15.8  1.0  0     0
# 3045  0.0  0.0  ...  Match Report    NaN   4.0   0.0  18.4  0.0  0     0
#
#      season         team
# 3265   2020    Barcelona
# 2437   2021  Real Madrid
# 1      2025    Barcelona
# 173    2024    Barcelona
# 3278   2020    Barcelona
# ...     ...          ...
# 895    2024   Valladolid
# 3621   2020        Cadiz
# 4187   2019      Granada
# 3609   2020        Cadiz
# 3045   2021        Cadiz
#
# [4700 rows x 29 columns]

# %% [markdown]
# Así a primera vista, parece que el Cádiz es el equipo con menor posesión de la competición cuando juega en la 1era división española de fútbol.

# %% [markdown]
# Los dataframes se pueden indexar de distinta manera. Con esto, podemos obtener filas únicas, es como hacer queries.

# %% [markdown]
# Por ejemplo, la media de goles a favor por partido:

# %%
data['gf'].mean()
# Out:
# np.float64(1.2736170212765958)

# %% [markdown]
# En 5 años, el promedio de goles por partido es de 1.27 goles por partido

# %%
data['referee'].value_counts()
# Out:
# referee
# César Soto                  252
# Ricardo de Burgos           240
# Jesús Gil                   240
# Pablo González              238
# José Luis Munuera           236
# Guillermo Cuadra            230
# Alejandro Hernández         228
# Juan Martínez               218
# Mario Melero                216
# José Sánchez                196
# Isidro Díaz de Mera         194
# Adrián Cordero              162
# Carlos del Cerro            160
# Alejandro Muñíz             156
# Miguel Ángel Ortiz Arias    156
# Jorge Figueroa              152
# Alberola Rojas              150
# Valentín Pizarro            140
# Antonio Matéu Lahoz         132
# Santiago Jaime              112
# Juan Pulido                 110
# Mateo Busquets               86
# Javier Estrada               84
# Francisco Hernández          84
# Víctor García                84
# Javier Alberola              80
# Javier Villanueva            80
# David Medié                  74
# Alejandro Quintero           46
# Jose Maria Sánchez           44
# Eduardo Prieto               36
# José González                36
# Antonio Matéu                26
# Miguel Sesma                  8
# Iosu Galech                   8
# José Guzmán                   6
# Name: count, dtype: int64

# %% [markdown]
# El colegiado que más partidos ha arbitrado en Primera División durante 5 temporadas (2019-2025), ha sido Cesar Soto, con 252 encuentros disputados. Seguido por De Burgos y Jesus Gil Manzano, con 240.

# %% [markdown]
# También esta el indexado condicional, que es lo más parecido a las queries de SQL.
#
# El **indexado condicional** de una columna también es algo muy útil. La sintaxix es `df[P(df['Name'])]`, donde  `P` es alguna condición lógica que es comprobada para cada elemento de la columna `Name`. El resultado de dicho indexado es el Dataframe que consta solo de las filas que satisfacen la condición `P` en la columna `Name`.

# %% [markdown]
# Por ejemplo, todos los partidos en los que se han anotado +3'5 goles por parte de algún equipo

# %%
data[data['gf'] >= 4].shape
# Out:
# (233, 29)

# %% [markdown]
# Otro ejemplo, cual es la posesión promedio de los partidos que terminan 0 a 0, para equipos que juegan en casa

# %% [markdown]
# Hay 233 partidos en los que ha habido más de 3 goles por parte de 1 de los 2 equipos

# %% [markdown]
# Apunte: En pandas no se puede usar 'and' en indexado condicional, se usa & y cada condición se envuelve en ().

# %%
data[(data['gf'] == 0) & (data['ga'] == 0) & (data['venue'] == 'Home')]['poss'].mean()
# Out:
# np.float64(50.83783783783784)

# %% [markdown]
# La posesión seria de casi el 51% cuando se juega en casa.

# %% [markdown]
# Los dataframes también los podemos indexar por el nombre de la columna (etiqueta) por el nombre de la fila (índice) o por el número de serie de una fila. El método `loc` se usa para indexar por nombre, mientras que el método `iloc()` se utiliza para indexar por número.

# %% [markdown]
# Por ejemplo: Los 3 primeros partidos del FC Barcelona

# %%
data.loc[data['team'] == 'Barcelona'].iloc[0:3]
# Out:
#    Unnamed: 0        date   time     comp        round  day venue result   gf  \
# 0           0  2025-08-16  19:30  La Liga  Matchweek 1  Sat  Away      W  3.0
# 1           1  2025-08-23  21:30  La Liga  Matchweek 2  Sat  Away      W  3.0
# 2           2  2025-08-31  21:30  La Liga  Matchweek 3  Sun  Away      D  1.0
#
#     ga  ...  match report  notes    sh   sot  dist   fk pk pkatt season  \
# 0  0.0  ...  Match Report    NaN  24.0   8.0  18.9  1.0  0     0   2025
# 1  2.0  ...  Match Report    NaN  26.0  10.0  17.0  1.0  0     0   2025
# 2  1.0  ...  Match Report    NaN  11.0   2.0  20.3  0.0  1     1   2025
#
#         team
# 0  Barcelona
# 1  Barcelona
# 2  Barcelona
#
# [3 rows x 29 columns]

# %%
data.loc[0, 'team']          # fila 0, columna 'team'
# Out:
# 'Barcelona'

# %%
data.loc[0:5]
# Out:
#    Unnamed: 0        date   time     comp        round  day venue result   gf  \
# 0           0  2025-08-16  19:30  La Liga  Matchweek 1  Sat  Away      W  3.0
# 1           1  2025-08-23  21:30  La Liga  Matchweek 2  Sat  Away      W  3.0
# 2           2  2025-08-31  21:30  La Liga  Matchweek 3  Sun  Away      D  1.0
# 3           3  2025-09-14  21:00  La Liga  Matchweek 4  Sun  Home      W  6.0
# 4           5  2025-09-21  21:00  La Liga  Matchweek 5  Sun  Home      W  3.0
# 5           6  2025-09-25  21:30  La Liga  Matchweek 6  Thu  Away      W  3.0
#
#     ga  ...  match report  notes    sh   sot  dist   fk pk pkatt season  \
# 0  0.0  ...  Match Report    NaN  24.0   8.0  18.9  1.0  0     0   2025
# 1  2.0  ...  Match Report    NaN  26.0  10.0  17.0  1.0  0     0   2025
# 2  1.0  ...  Match Report    NaN  11.0   2.0  20.3  0.0  1     1   2025
# 3  0.0  ...  Match Report    NaN  24.0  10.0  18.4  0.0  0     0   2025
# 4  0.0  ...  Match Report    NaN  16.0   7.0  18.2  2.0  0     0   2025
# 5  1.0  ...  Match Report    NaN  22.0  10.0  16.5  1.0  0     0   2025
#
#         team
# 0  Barcelona
# 1  Barcelona
# 2  Barcelona
# 3  Barcelona
# 4  Barcelona
# 5  Barcelona
#
# [6 rows x 29 columns]

# %% [markdown]
# Por ejemplo, aqui obtenemos los valores de los primeros 5 partidos en las 8 primeras filas.

# %%
data.iloc[0:5, 0:8]
# Out:
#    Unnamed: 0        date   time     comp        round  day venue result
# 0           0  2025-08-16  19:30  La Liga  Matchweek 1  Sat  Away      W
# 1           1  2025-08-23  21:30  La Liga  Matchweek 2  Sat  Away      W
# 2           2  2025-08-31  21:30  La Liga  Matchweek 3  Sun  Away      D
# 3           3  2025-09-14  21:00  La Liga  Matchweek 4  Sun  Home      W
# 4           5  2025-09-21  21:00  La Liga  Matchweek 5  Sun  Home      W

# %% [markdown]
# Para obtener la primera o última instancia de un dataframe, podemos usar respectivamente `df[:1]` y `df[-1:]`.

# %% [markdown]
# También se puede aplicar funciones a las celdas, columnas y filas de un dataframe.

# %% [markdown]
# Para aplicar funciones a una columna se usa el método `apply()`. Por ejemplo, a continuación mostramos cómo obtener el valor máximo de los distintos descriptores del dataset.

# %% [markdown]
# Primero, empezamos importando `numpy` que es una librería de análisis numérico.
#
# Básicamente es una librería para trabajar con arrays multidimensionales de forma muy eficiente. Pandas está construido encima de NumPy.

# %%
import numpy as np

# %% [markdown]
# Por ejemplo, obtenemos el valor máximo para cada una de las columnas de nuestro dataset

# %%
data.apply(np.max)
# Out:
# Unnamed: 0                    60
# date                  2025-09-30
# time                       22:15
# comp                     La Liga
# round                Matchweek 9
# day                          Wed
# venue                       Home
# result                         W
# gf                           7.0
# ga                           7.0
# opponent              Villarreal
# xg                           5.9
# xga                          5.9
# poss                        82.0
# attendance               95745.0
# captain          Óscar de Marcos
# formation                  5-4-1
# opp formation              5-4-1
# referee            Víctor García
# match report        Match Report
# notes                        NaN
# sh                          40.0
# sot                         17.0
# dist                        46.2
# fk                           5.0
# pk                             3
# pkatt                          3
# season                      2025
# team                  Villarreal
# dtype: object

# %% [markdown]
# También se puede aplicar a filas, solo hay que utilizar `axis=1`.
# Las funciones lambda suelen ser muy útiles en estos casos.

# %% [markdown]
# Por ejemplo, partidos donde el resultado empieza por W que son Victorias (no es muy útil pero como ejemplo sirve, ya que con hacer data[data['result'] == 'W'] lo tienes

# %%
data[data['result'].apply(lambda x: x.startswith('W'))]
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 0              0  2025-08-16  19:30  La Liga   Matchweek 1  Sat  Away      W
# 1              1  2025-08-23  21:30  La Liga   Matchweek 2  Sat  Away      W
# 3              3  2025-09-14  21:00  La Liga   Matchweek 4  Sun  Home      W
# 4              5  2025-09-21  21:00  La Liga   Matchweek 5  Sun  Home      W
# 5              6  2025-09-25  21:30  La Liga   Matchweek 6  Thu  Away      W
# ...          ...         ...    ...      ...           ...  ...   ...    ...
# 4665           9  2019-09-15  12:00  La Liga   Matchweek 4  Sun  Away      W
# 4671          18  2019-10-27  16:00  La Liga  Matchweek 10  Sun  Away      W
# 4681          31  2020-01-19  16:00  La Liga  Matchweek 20  Sun  Away      W
# 4684          35  2020-02-09  12:00  La Liga  Matchweek 23  Sun  Home      W
# 4689          42  2020-06-13  14:00  La Liga  Matchweek 28  Sat  Home      W
#
#        gf   ga  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0     3.0  0.0  ...  Match Report    NaN  24.0   8.0  18.9  1.0  0     0
# 1     3.0  2.0  ...  Match Report    NaN  26.0  10.0  17.0  1.0  0     0
# 3     6.0  0.0  ...  Match Report    NaN  24.0  10.0  18.4  0.0  0     0
# 4     3.0  0.0  ...  Match Report    NaN  16.0   7.0  18.2  2.0  0     0
# 5     3.0  1.0  ...  Match Report    NaN  22.0  10.0  16.5  1.0  0     0
# ...   ...  ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 4665  2.0  1.0  ...  Match Report    NaN   7.0   2.0  16.8  0.0  0     0
# 4671  1.0  0.0  ...  Match Report    NaN  14.0   3.0  17.6  1.0  0     0
# 4681  2.0  1.0  ...  Match Report    NaN  16.0   5.0  16.9  0.0  0     0
# 4684  1.0  0.0  ...  Match Report    NaN  12.0   7.0  16.8  0.0  0     0
# 4689  2.0  0.0  ...  Match Report    NaN  19.0   9.0  17.3  2.0  0     0
#
#      season       team
# 0      2025  Barcelona
# 1      2025  Barcelona
# 3      2025  Barcelona
# 4      2025  Barcelona
# 5      2025  Barcelona
# ...     ...        ...
# 4665   2019   Espanyol
# 4671   2019   Espanyol
# 4681   2019   Espanyol
# 4684   2019   Espanyol
# 4689   2019   Espanyol
#
# [1712 rows x 29 columns]

# %% [markdown]
# Otro ejemplo:
#  Mediante una lambda, y aplicando a filas, podemos clasificar los resultados en puntos:
#
# - W: 3 pts
#
# - D: 1 pts
#
# - L: 0 pts

# %%
data['points'] = data['result'].apply(lambda x: 3 if x == 'W' else 1 if x == 'D' else 0)

# %% [markdown]
# Además, en este ejemplo hemos creado una nueva entrada en nuestro dataframe, añadiendo el descriptor points o puntos como nueva columna

# %%
data.shape
# Out:
# (4700, 30)

# %% [markdown]
# Ahora tendríamos 30 descriptores

# %%
data['points'].describe()
# Out:
# count    4700.000000
# mean        1.364255
# std         1.299598
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max         3.000000
# Name: points, dtype: float64

# %% [markdown]
# El método `map` se puede utilizar para reemplazar valores en una columna pasándole un diccionario de la forma `{old_value: new_value}` como argumento:

# %% [markdown]
# Convierto de W/D/L a Victoria/Empate/Derrota

# %%
data['result'] = data['result'].map({'W': 'Victoria', 'D': 'Empate', 'L' : 'Derrota'})

# %%
data['result'].value_counts()
# Out:
# result
# Victoria    1712
# Derrota     1712
# Empate      1276
# Name: count, dtype: int64

# %% [markdown]
# Agrupaciones. Para construir grupos de datos en Pandas, utilizamos generalmente una construcción como la siguiente.

# %% [markdown]
# ```python
# df.groupby(by=grouping_columns)[columns_to_show].function()
# ```

# %% [markdown]
# 1. Primero, el método `groupby` divide `grouping_columns` por sus valores, que se convierten en un nuevo índice en el dataframe resultante.
# 2. Seguidamente, las columnas de interés se seleccionan (`columns_to_show`). Si no se incluye `columns_to_show` se muestran todas las clausulas que no hayan sido agrupadas.
# 3. Finalmente, una o varias funciones se aplican para obtener los grupos por las columnas seleccionadas.

# %% [markdown]
# Por ejemplo, las siguientes agrupaciones son bastante útiles

# %% [markdown]
# Media de goles por equipo:

# %%
data.groupby('team')['gf'].mean()
# Out:
# team
# Alaves             0.918782
# Almeria            1.210526
# Athletic Club      1.272340
# Atletico Madrid    1.723404
# Barcelona          2.174468
# Cadiz              0.835526
# Celta Vigo         1.229787
# Eibar              0.894737
# Elche              0.942149
# Espanyol           1.062893
# Getafe             0.944681
# Girona             1.570248
# Granada            1.190789
# Huesca             0.894737
# Las Palmas         0.960526
# Leganes            0.907895
# Levante            1.280992
# Mallorca           0.949239
# Osasuna            1.085106
# Oviedo             0.571429
# Rayo Vallecano     1.012579
# Real Betis         1.370213
# Real Madrid        2.012766
# Real Sociedad      1.272340
# Sevilla            1.310638
# Valencia           1.187234
# Valladolid         0.822368
# Villarreal         1.676596
# Name: gf, dtype: float64

# %% [markdown]
# El Barcelona es el equipo que más goles ha promediado en estas 5 últimas temporadas, con 2.17 goles por partido. Seguido por el Real Madrid, con 2.01
#
# El Real Oviedo es el equipo con menos goles promediado por encuentro que ha pasado por LaLiga en estos últimos 5 años.

# %% [markdown]
# Victorias, derrotas y empates por equipo

# %%
data.groupby(['team', 'result']).size()
# Out:
# team        result
# Alaves      Derrota      95
#             Empate       51
#             Victoria     51
# Almeria     Derrota      42
#             Empate       20
#                        ...
# Valladolid  Empate       42
#             Victoria     29
# Villarreal  Derrota      69
#             Empate       59
#             Victoria    107
# Length: 83, dtype: int64

# %% [markdown]
# Puntos totales de cada equipo por temporada.

# %%
data.groupby(['team', 'season'])['points'].sum()
# Out:
# team        season
# Alaves      2019      39
#             2020      38
#             2021      31
#             2023      46
#             2024      42
#                       ..
# Villarreal  2021      59
#             2022      64
#             2023      53
#             2024      70
#             2025      16
# Name: points, Length: 140, dtype: int64

# %% [markdown]
# Si quisieramos mostrar este último ejemplo completo, podemos utilizar `reset_index` que convierte el índice jerárquico en columnas normales y muestra todo como un DataFrame limpio.

# %% [markdown]
# Estadísticas de posesión y xG por resultado

# %%
data.groupby('result')[['poss', 'xg', 'sh']].mean()
# Out:
#                poss        xg         sh
# result
# Derrota   48.732477  0.956659  10.663551
# Empate    50.001567  1.125862  11.328370
# Victoria  51.269276  1.675759  12.602220
